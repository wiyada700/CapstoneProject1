# %% [markdown]
# # Capstone Project.

# %% [markdown]
# # 1. Import necessary Libraries.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %% [markdown]
# # Define Foursquare Credentials and Version

# %%
CLIENT_ID = '5HLP2QXBAKWBMQJ4GIHI5DV3L152R254Q3IYWCPKYLBNV2NU' # your Foursquare ID
CLIENT_SECRET = 'TQ3EWXAE2KKEVLXFT0BDKY4XGMSNJY5BLZ2M1L3MJQILFPIN' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5HLP2QXBAKWBMQJ4GIHI5DV3L152R254Q3IYWCPKYLBNV2NU
# CLIENT_SECRET:TQ3EWXAE2KKEVLXFT0BDKY4XGMSNJY5BLZ2M1L3MJQILFPIN

# %% [markdown]
# # This is my place for converting to latitude and longtitude address in Bangkok.

# %%
address = 'Bangkok,Thailand'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 13.7542529 100.493087

# %% [markdown]
# # Search for a specific venue category in Bangkok.

# %%
search_query = 'Indian'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %% [markdown]
# Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5HLP2QXBAKWBMQJ4GIHI5DV3L152R254Q3IYWCPKYLBNV2NU&client_secret=TQ3EWXAE2KKEVLXFT0BDKY4XGMSNJY5BLZ2M1L3MJQILFPIN&ll=13.7542529,100.493087&v=20180604&query=Indian&radius=1000&limit=30'

# %% [markdown]
# Send the GET Request and examine the results of Indian in Bangkok.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1e539751d07f34bc17af7c'},
#  'response': {'venues': [{'id': '4ccd69b3ba79a1cd094b41cb',
#     'name': 'Indian Food@KaoSarn',
#     'location': {'address': '2nd floor',
#      'lat': 13.758908402696001,
#      'lng': 100.49710607195487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.758908402696001,
#        'lng': 100.49710607195487}],
#      'distance': 676,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['2nd floor',
#       'ตลาดยอด',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595823037',
# ...

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
#
#                          id        location.address location.cc location.city  \
# 0  4ccd69b3ba79a1cd094b41cb               2nd floor          TH        พระนคร
# 1  4c7905cb93ef236a0f05ae0f            Indra square          TH     ทุ่งพญาไท
# 2  5dd4d376828ea10008f6b2a1    19 Soi Chanasongkram          TH        พระนคร
# 3  4dda11541f6ee14683620257  86/2 2 fl Soi Rambutri          TH        พระนคร
# 4  4c4acda0c668e21e581426f9                     NaN          TH        พระนคร
#
#   location.country       location.crossStreet  location.distance  \
# ...

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                            name         categories                 address  \
# 0           Indian Food@KaoSarn  Indian Restaurant               2nd floor
# 1   Bombay - Palace Indian Food  Indian Restaurant            Indra square
# 2        Indian Kebab & Curries  Indian Restaurant    19 Soi Chanasongkram
# 3                   Star Indian  Indian Restaurant  86/2 2 fl Soi Rambutri
# 4          Om Indian Restaurant  Indian Restaurant                     NaN
# 5          Sidewalk Indian food  Indian Restaurant                     NaN
# 6                  Royal Indian  Indian Restaurant                Kao Sarn
# 7                  Chilli Chill  Indian Restaurant         Chakraphong Rd.
# 8          Taj Mahal Restaurant  Indian Restaurant                     NaN
# 9                       Saffron  Indian Restaurant                     NaN
# 10                 New Tajmahal  Indian Restaurant                     NaN
# ...

# %% [markdown]
# #### Let's visualize the Indian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0             Indian Food@KaoSarn
# 1     Bombay - Palace Indian Food
# 2          Indian Kebab & Curries
# 3                     Star Indian
# 4            Om Indian Restaurant
# 5            Sidewalk Indian food
# 6                    Royal Indian
# 7                    Chilli Chill
# 8            Taj Mahal Restaurant
# 9                         Saffron
# 10                   New Tajmahal
# 11                          Santi
# 12                 Taste of India
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # This is my place for converting to latitude and longtitude address in Nakhon Ratchasima.

# %%
address = 'Nakhon Ratchasima,Thailand'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 15.2241917 101.9313754

# %% [markdown]
# # Search for a specific venue category in Nakhon Ratchasima.

# %%
search_query = 'Indian'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5HLP2QXBAKWBMQJ4GIHI5DV3L152R254Q3IYWCPKYLBNV2NU&client_secret=TQ3EWXAE2KKEVLXFT0BDKY4XGMSNJY5BLZ2M1L3MJQILFPIN&ll=15.2241917,101.9313754&v=20180604&query=Indian&radius=1000&limit=30'

# %% [markdown]
# Send the GET Request and examine the results of Indial in Nakhon Ratchasima.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1e568b51d07f34bc1e3078'},
#  'response': {'venues': []}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
